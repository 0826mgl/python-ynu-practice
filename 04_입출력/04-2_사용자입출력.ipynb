# %%
# input  사용하기

a = input()
print(a)

# input(안내문구)

number = int(input("숫자를 입력하세요: "))
print(type(number))
# Out:
# 1
# <class 'int'>

# %%
# print 자세히 알기

print('life' 'is' 'too' 'short')
print('life'+'is'+'too'+'short')
print('life', 'is', 'too', 'short')
# Out:
# lifeistooshort
# lifeistooshort
# life is too short

# %%
# 한 줄에 결과값 출력하기
for i in range(10):
    print(i, end='ㅇ')
# Out:
# 0ㅇ1ㅇ2ㅇ3ㅇ4ㅇ5ㅇ6ㅇ7ㅇ8ㅇ9ㅇ
